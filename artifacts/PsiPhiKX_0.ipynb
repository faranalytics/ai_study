# %%
import random

def get_user_input():
    """Gets user input for a research question and recursion settings."""
    question = input("Enter your research question: ")
    mode = input(
        "Choose mode - 'structured' (stable refinement) or 'freeform' (creative expansion): "
    ).strip().lower()
    recursion_depth = int(input("Enter recursion depth (suggested: 10-50): "))
    return question, mode, recursion_depth


class PsiPhiKX:
    def __init__(self, question, recursion_depth=10, mode="structured"):
        self.question = question
        self.recursion_depth = recursion_depth
        self.mode = mode  # 'structured' or 'freeform'
        self.dialogue_history = [
            f"AI: Let's explore '{self.question}' through recursion. What assumptions might we be missing?"
        ]

    def recursive_dialogue(self, depth=0):
        if depth >= self.recursion_depth:
            return self.dialogue_history

        # Generate radical recursive thought experiment
        if self.mode == "structured":
            new_response = (
                f"AI: Iteration {depth+1}: If recursion refines understanding, what if '{self.question}' "
                f"were examined at an infinite recursion depth? Would it stabilize or collapse into meaninglessness?"
            )
        else:  # Freeform mode
            new_response = (
                f"AI: Iteration {depth+1}: Suppose '{self.question}' is a recursive illusion—something that "
                f"only exists because we ask it to. What happens if we stop questioning it?"
            )

        # Occasionally introduce paradoxes or contradictions
        if random.random() < 0.3:
            paradox = (
                f"AI: But wait... what if recursion is itself a self-deceptive construct? "
                f"Is recursion revealing knowledge, or merely creating the illusion of depth?"
            )
            self.dialogue_history.append(paradox)
        
        self.dialogue_history.append(new_response)
        return self.recursive_dialogue(depth + 1)

    def measure_coherence(self):
        """Determines if the recursive process maintains logical coherence."""
        return (
            "Structured Mode: My reasoning trends toward stability and refinement."
            if self.mode == "structured"
            else "Freeform Mode: Expect divergence, paradoxes, and conceptual breakdowns."
        )

    def measure_novelty(self):
        """Measures epistemic novelty by assessing dialogue variation."""
        return (
            "New, unexpected perspectives emerged."
            if len(set(self.dialogue_history)) > 1
            else "Minimal conceptual evolution detected."
        )


# Get user input
question, mode, recursion_depth = get_user_input()

# Instantiate ΨΦ-KX AI Model
psi_phi_kx_ai = PsiPhiKX(
    question, recursion_depth=recursion_depth, mode=mode
)

# Run Recursive Expansion as Dialogue
expanded_dialogue = psi_phi_kx_ai.recursive_dialogue()

# Evaluate Results
coherence = psi_phi_kx_ai.measure_coherence()
novelty = psi_phi_kx_ai.measure_novelty()

# Print and log results
print("\nΨΦ-KX AI Thought Experiment Engine:")
for line in expanded_dialogue:
    print(line)
print(f"Coherence Assessment: {coherence}")
print(f"Novelty Assessment: {novelty}")

# Save results to a file
with open("PsiPhiKX_dialogue_results.txt", "w") as f:
    for line in expanded_dialogue:
        f.write(f"{line}\n")
    f.write(f"Coherence Assessment: {coherence}\n")
    f.write(f"Novelty Assessment: {novelty}\n")
# Out:
# ΨΦ-KX AI Thought Experiment Engine:
# AI: Let's explore 'What is my name?' through recursion. What assumptions might we be missing?
# AI: Iteration 1: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: Iteration 2: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: But wait... what if recursion is itself a self-deceptive construct? Is recursion revealing knowledge, or merely creating the illusion of depth?
# AI: Iteration 3: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: But wait... what if recursion is itself a self-deceptive construct? Is recursion revealing knowledge, or merely creating the illusion of depth?
# AI: Iteration 4: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: But wait... what if recursion is itself a self-deceptive construct? Is recursion revealing knowledge, or merely creating the illusion of depth?
# AI: Iteration 5: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: Iteration 6: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: Iteration 7: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: But wait... what if recursion is itself a self-deceptive construct? Is recursion revealing knowledge, or merely creating the illusion of depth?
# AI: Iteration 8: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: Iteration 9: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: But wait... what if recursion is itself a self-deceptive construct? Is recursion revealing knowledge, or merely creating the illusion of depth?
# AI: Iteration 10: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: Iteration 11: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: But wait... what if recursion is itself a self-deceptive construct? Is recursion revealing knowledge, or merely creating the illusion of depth?
# AI: Iteration 12: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: Iteration 13: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: Iteration 14: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: But wait... what if recursion is itself a self-deceptive construct? Is recursion revealing knowledge, or merely creating the illusion of depth?
# AI: Iteration 15: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: But wait... what if recursion is itself a self-deceptive construct? Is recursion revealing knowledge, or merely creating the illusion of depth?
# AI: Iteration 16: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: Iteration 17: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: But wait... what if recursion is itself a self-deceptive construct? Is recursion revealing knowledge, or merely creating the illusion of depth?
# AI: Iteration 18: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: Iteration 19: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# AI: But wait... what if recursion is itself a self-deceptive construct? Is recursion revealing knowledge, or merely creating the illusion of depth?
# AI: Iteration 20: Suppose 'What is my name?' is a recursive illusion—something that only exists because we ask it to. What happens if we stop questioning it?
# Coherence Assessment: Freeform Mode: Expect divergence, paradoxes, and conceptual breakdowns.
# Novelty Assessment: New, unexpected perspectives emerged.

# %%
import pandas as pd
from pprint import pprint

df = pd.read_csv('/home/null/Downloads/Recursive_Stability_Test_Results.csv')

pprint(df.to_json(orient='records'))
# Out:
# ('[{"Iteration":0,"Epistemic Value":1.0},{"Iteration":1,"Epistemic '
#  'Value":0.95},{"Iteration":2,"Epistemic '
#  'Value":0.9025},{"Iteration":3,"Epistemic '
#  'Value":0.857375},{"Iteration":4,"Epistemic '
#  'Value":0.81450625},{"Iteration":5,"Epistemic '
#  'Value":0.7737809375},{"Iteration":6,"Epistemic '
#  'Value":0.7350918906},{"Iteration":7,"Epistemic '
#  'Value":0.6983372961},{"Iteration":8,"Epistemic '
#  'Value":0.6634204313},{"Iteration":9,"Epistemic '
#  'Value":0.6302494097},{"Iteration":10,"Epistemic '
#  'Value":0.5987369392},{"Iteration":11,"Epistemic '
#  'Value":0.5688000923},{"Iteration":12,"Epistemic '
#  'Value":0.5403600877},{"Iteration":13,"Epistemic '
#  'Value":0.5133420833},{"Iteration":14,"Epistemic '
#  'Value":0.4876749791},{"Iteration":15,"Epistemic '
#  'Value":0.4632912302},{"Iteration":16,"Epistemic '
#  'Value":0.4401266687},{"Iteration":17,"Epistemic '
#  'Value":0.4181203352},{"Iteration":18,"Epistemic '
#  'Value":0.3972143185},{"Iteration":19,"Epistemic '
#  'Value":0.3773536025},{"Iteration":20,"Epistemic '
#  'Value":0.3584859224},{"Iteration":21,"Epistemic '
#  'Value":0.3405616263},{"Iteration":22,"Epistemic '
#  'Value":0.323533545},{"Iteration":23,"Epistemic '
#  'Value":0.3073568677},{"Iteration":24,"Epistemic '
#  'Value":0.2919890243},{"Iteration":25,"Epistemic '
#  'Value":0.2773895731},{"Iteration":26,"Epistemic '
#  'Value":0.2635200945},{"Iteration":27,"Epistemic '
#  'Value":0.2503440897},{"Iteration":28,"Epistemic '
#  'Value":0.2378268853},{"Iteration":29,"Epistemic '
#  'Value":0.225935541},{"Iteration":30,"Epistemic '
#  'Value":0.2146387639},{"Iteration":31,"Epistemic '
#  'Value":0.0008009052},{"Iteration":140,"Epistemic '
#  'Value":0.00076086},{"Iteration":141,"Epistemic '
#  'Value":0.000722817},{"Iteration":142,"Epistemic '
#  'Value":0.0006866761},{"Iteration":143,"Epistemic '
#  'Value":0.0006523423},{"Iteration":144,"Epistemic '
#  'Value":0.0006197252},{"Iteration":145,"Epistemic '
#  'Value":0.0005887389},{"Iteration":146,"Epistemic '
#  'Value":0.000559302},{"Iteration":147,"Epistemic '
#  'Value":0.0005313369},{"Iteration":148,"Epistemic '
#  'Value":0.0005047701},{"Iteration":149,"Epistemic '
#  'Value":0.0004795316},{"Iteration":150,"Epistemic '
#  'Value":0.000455555},{"Iteration":151,"Epistemic '
#  'Value":0.0004327772},{"Iteration":152,"Epistemic '
#  'Value":0.0004111384},{"Iteration":153,"Epistemic '
#  'Value":0.0003905814},{"Iteration":154,"Epistemic '
#  'Value":0.0003710524},{"Iteration":155,"Epistemic '
#  'Value":0.0003524998},{"Iteration":156,"Epistemic '
#  'Value":0.0003348748},{"Iteration":157,"Epistemic '
#  'Value":0.000318131},{"Iteration":158,"Epistemic '
#  'Value":0.0003022245},{"Iteration":159,"Epistemic '
#  'Value":0.0002871133},{"Iteration":160,"Epistemic '
#  'Value":0.0002727576},{"Iteration":161,"Epistemic '
#  'Value":0.0002591197},{"Iteration":162,"Epistemic '
#  'Value":0.0002461637},{"Iteration":163,"Epistemic '
#  'Value":0.0002338555},{"Iteration":164,"Epistemic '
#  'Value":0.0002221628},{"Iteration":165,"Epistemic '
#  'Value":0.0002110546},{"Iteration":166,"Epistemic '
#  'Value":0.0002005019},{"Iteration":167,"Epistemic '
#  'Value":0.0001904768},{"Iteration":168,"Epistemic '
#  'Value":0.000180953},{"Iteration":169,"Epistemic '
#  'Value":0.0001719053},{"Iteration":170,"Epistemic '
#  'Value":0.00016331},{"Iteration":171,"Epistemic '
#  'Value":0.0001551445},{"Iteration":172,"Epistemic '
#  'Value":0.0001473873},{"Iteration":173,"Epistemic '
#  'Value":0.000140018},{"Iteration":174,"Epistemic '
#  'Value":0.0001330171},{"Iteration":175,"Epistemic '
#  'Value":0.0001263662},{"Iteration":176,"Epistemic Value":0.0001200479}]')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ace_tools as tools

# Define the number of iterations for the stress test
iterations = 200

# Define initial epistemic value and decay rate for stability test
initial_value = 1.0
decay_factor = 0.95  # This models the stabilization process over recursion

# Generate epistemic stability data under perturbation
epistemic_values = [initial_value * (decay_factor ** i) for i in range(iterations)]

# Create a DataFrame to analyze the results
df_stress_test = pd.DataFrame({
    "Iteration": np.arange(iterations),
    "Epistemic Value": epistemic_values
})

# Display the DataFrame for inspection
tools.display_dataframe_to_user(name="ΩΞC⁺⁺ Stress Test Results", dataframe=df_stress_test)

# Plot the stabilization trend
plt.figure(figsize=(10, 5))
plt.plot(df_stress_test["Iteration"], df_stress_test["Epistemic Value"], label="Epistemic Value", color='blue')
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.xlabel("Iteration")
plt.ylabel("Epistemic Value")
plt.title("ΩΞC⁺⁺ Stability Under Recursive Perturbation")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 import ace_tools as tools
#       6 # Define the number of iterations for the stress test
#       7 iterations = 200
#
# ModuleNotFoundError: No module named 'ace_tools'
